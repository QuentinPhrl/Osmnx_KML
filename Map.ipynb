# %%
import osmnx as ox
city_list = ['Albi','Le Sequestre']
G = ox.graph_from_place(city_list, network_type='drive_service',simplify=True)
G = ox.add_edge_speeds(G)
G = ox.add_edge_travel_times(G)
#fig, ax = ox.plot_graph(ox.project_graph(G))
# Out:
# /home/kali/miniconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /home/kali/miniconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /home/kali/miniconda3/envs/ox/lib/python3.9/site-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# ...

# %%
import matplotlib.pyplot as plt
import random

number_of_colors = 30

color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
print(color)
# Out:
# ['#537843', '#E19A63', '#C3FA3B', '#1061DC', '#FF57C6', '#606B3C', '#E84C8D', '#E2FF1E', '#9EAF4A', '#6FF718', '#16395D', '#663F96', '#48CAB3', '#1F29F5', '#D0F145', '#C8832B', '#79F658', '#0EF995', '#759D38', '#515C72', '#157A14', '#E0A935', '#A68990', '#1BBCA2', '#A2740B', '#9F0F92', '#6BEFDA', '#4060D9', '#EBD330', '#FB6F85']

# %%
route_list = [
#43.9190181, 2.1811683,
#43.931514, 2.1526984,
43.931514, 2.1526984,
43.9323575, 2.1454085999999997,
43.931514, 2.1526984,
43.9251318, 2.1491958,
43.924328, 2.173726,
43.9247173, 2.1657039,
43.9229347, 2.1663709,
43.921398, 2.1668048,
43.924328, 2.173726,
43.949678, 2.152634,
43.924328, 2.173726,
43.924328, 2.173726,
43.9227877, 2.1470536,
43.9182489, 2.1149057,
43.9199952, 2.1500243,
43.924328, 2.173726,
43.924328, 2.173726,
43.9265207, 2.141309,
43.9259574, 2.1390348,
43.9148616, 2.1265496,
43.917921899999996, 2.1309963,
43.924328, 2.173726,
43.924328, 2.173726,
43.924328, 2.173726,
43.9235424, 2.1576447,
43.9258451, 2.1454545,
43.9233925, 2.1443922,
43.923667099999996, 2.1501915,
43.9278638, 2.1440165,
43.946057, 2.136373,
43.942071, 2.143894
]
route_liste_def = []
import networkx as nx

origin_node_test = ox.distance.nearest_nodes(G, 43.921933, 8.121039)
destination_node_test = ox.distance.nearest_nodes(G, 100.950727, 3.152444)

    
for i in range(0, 60,2):
    
    origin_point = (route_list[i],route_list[i+1])
    destination_point = (route_list[i+2],route_list[i+3])
    
    origin_node = ox.get_nearest_node(G, origin_point)
    destination_node = ox.get_nearest_node(G, destination_point)

    route = ox.distance.shortest_path(G, origin_node, destination_node, weight='length')
    
    route_liste_def.append(route)

fig, ax = ox.plot_graph_routes(G, route_liste_def, route_colors=color, route_linewidth=6, node_size=0, bgcolor='k',figsize=(30, 30))
# Out:
# /home/kali/miniconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /home/kali/miniconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /home/kali/miniconda3/envs/ox/lib/python3.9/site-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# ...
